# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranavi-chowdary99/Pranavi_HDS/blob/main/week14_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 14 Programming Assignment
#
# As you're working on identifying data for your final project, it's helpful to spend some time exploring your various data files.  For this week's assignment, I'd like you to take a few of the ideas from the the lectures, review assignment, and tonight's lecture to start exploring the data you plan to use for the final project.
#
# For the following activities, you can use just one of the data files that you've identified, or you can do the activities using different data files.  That's up to you.  Please describe what you're doing in a Markdown cell or in the comments of your code.  When you've completed the assignment, submit it as normal.

# %% [markdown]
# ### 1. Basic Statistics
#
# Use Python to read in your data file and show many rows and columns your data has.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
drugsin_the_world = pd.read_csv('Preval nac.usodrogasincl.NPS.csv')
drugsin_the_world
# Out:
#                      NEW PSYCHOACTIVE SUBSTANCES (NPS) Unnamed: 1  \
# 0    Prevalence of Use as a percentage of the popul...        NaN
# 1                                             NPS Type     Region
# 2                                                  NaN        NaN
# 3                               Synthetic cannabinoids     Africa
# 4                                                  NaN   Americas
# ..                                                 ...        ...
# 251                                                NaN        NaN
# 252                                                NaN        NaN
# 253                                                NaN        NaN
# 254                                                NaN        NaN
# 255                                                NaN        NaN
#
#         Unnamed: 2                          Unnamed: 3  \
# 0              NaN                                 NaN
# 1       Sub-region                   Country/Territory
# ...

# %% [markdown]
# in this dataset we have 256 rows and 17 columns

# %% [markdown]
# ### 2. Data Diversity
#
# Use Python to identify how many unique values each column in your data has.  Use Python to identify which column has the greatest number of distinct values (aka the most diversity)?  If your data has a unique identifier (e.g. a person or visit or record ID) then find the column with the next most number of unique values.

# %%
unique_values_per_column = drugsin_the_world.nunique()

# Sort columns by the number of unique values
sorted_unique_values = unique_values_per_column.sort_values(ascending=False)
max_unique_column = sorted_unique_values.index[0]
max_unique_value_count = sorted_unique_values.iloc[0]

# Print results
print("Number of unique values per column:")
print(unique_values_per_column)

print(f"\nThe column with the most diversity is '{max_unique_column}' with {max_unique_value_count} unique values.")
# Out:
# Number of unique values per column:
# NEW PSYCHOACTIVE SUBSTANCES (NPS)     6
# Unnamed: 1                            6
# Unnamed: 2                           11
# Unnamed: 3                           56
# Unnamed: 4                           18
# Unnamed: 5                           75
# Unnamed: 6                           66
# Unnamed: 7                           48
# Unnamed: 8                           62
# Unnamed: 9                           52
# Unnamed: 10                          38
# Unnamed: 11                          34
# Unnamed: 12                          30
# Unnamed: 13                          21
# Unnamed: 14                          34
# Unnamed: 15                          23
# Unnamed: 16                          65
# dtype: int64
#
# The column with the most diversity is 'Unnamed: 5' with 75 unique values.

# %% [markdown]
# ### 3. Data Redundancy
#
# Use Python to identify any columns in your data where the value for every row is the same.  For example, if you had a gender column and all the rows said 'M', then you would want to write the code that helped you determine that.

# %%
# Find columns where all rows have the same value
columns_with_same_values = [col for col in drugsin_the_world.columns if drugsin_the_world[col].nunique() == 1]

# Print the results
print("Columns where the value for every row is the same:")
print(columns_with_same_values)
# Out:
# Columns where the value for every row is the same:
# []

# %%
# Print each column and its unique value
# Iterate through each column in the list of columns with the same value
for column in columns_with_same_values:
    # Extract the unique value (since all rows have the same value)
    unique_value = Mental_health[column].unique()[0]

    # Print the column name and its unique value
    print(f"Column: {column}")
    print(f"Unique Value: {unique_value}\n")

# %% [markdown]
# ### 4. Range of Values
#
# Your data almost certainly has some numeric columns that can be summed or averaged.  Create a histogram that shows the distribution of values for this column.

# %%
numeric_column = 'Unnamed: 2'

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(drugsin_the_world[numeric_column].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.title(f'Distribution of {numeric_column}')
plt.xlabel(numeric_column)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 5. Discussion
#
# Do any additional exploration of this data that you think may be interesting and include your code here.  Then go onto Slack and make a post about what you've observed.  Share your observation.  Share your code, if you like.  Share a screenshot of the data or a chart based on the data.
#
# Then comment on at least two other people's observations that they share on Slack.  (Use the reply as thread option in Slack to keep the conversation organized.)

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x='Unnamed: 3', y='Unnamed: 4', data=drugsin_the_world)
plt.xticks(rotation=20, ha='right')
plt.title('Time Series of Value')
plt.show()

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# Submit your work as usual.
